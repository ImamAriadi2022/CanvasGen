# %% [markdown]
# # Streamlit Submission - CanvasGen AI Studio Web App
# **Nama Peserta**: Imam Ariadi
# **Program**: Beasiswa IDCamp / BFG AI
# **Proyek**: CanvasGen Streamlit Web Interface dan Deployment Setup
#
# ---

# %% [markdown]
# ## 1. Pendahuluan
# Notebook ini menyajikan dokumentasi alur pembuatan, konfigurasi lingkungan, pengujian lokal, dan deployment aplikasi web CanvasGen menggunakan Streamlit.

# %% [markdown]
# ## 2. Penyiapan Lingkungan dan Dependensi

# %%
# Memeriksa instalasi Streamlit
import streamlit as st
print(f"Versi Streamlit terpasang: {st.__version__}")
# Out:
# Error on cell #1: No module named 'streamlit.proto'

# %% [markdown]
# ## 3. Kode Sumber Aplikasi Web Streamlit (`app.py`)
# Aplikasi web dikembangkan secara terpisah di `app.py` menggunakan arsitektur fasad `GenerationService`.

# %%
# Membaca dan menampilkan struktur kode app.py
with open('app.py', 'r', encoding='utf-8') as f:
    app_code = f.read()

print(f"Ukuran file app.py: {len(app_code)} karakter")
print("Baris pertama app.py:", app_code.splitlines()[:5])
# Out:
# Ukuran file app.py: 12251 karakter
# Baris pertama app.py: ['"""CanvasGen - Aplikasi Web Generasi Gambar Berbasis AI menggunakan Streamlit."""', '', 'import io', 'from typing import Optional', 'from PIL import Image, ImageDraw']

# %% [markdown]
# ## 4. Alur Menjalankan Aplikasi Streamlit Secara Lokal
# Untuk menjalankan aplikasi web Streamlit secara lokal di browser Anda, gunakan perintah terminal berikut:

# %%
# Perintah untuk menjalankan Streamlit di lingkungan lokal:
# streamlit run app.py
print("Perintah eksekusi lokal: streamlit run app.py")
# Out:
# Perintah eksekusi lokal: streamlit run app.py

# %% [markdown]
# ## 5. Deployment Ngrok (Opsional)
# Jika ingin mendistribusikan aplikasi dari Cloud menggunakan Ngrok, gunakan script placeholder di bawah ini.

# %%
# Placeholder Ngrok Tunneling Setup
print("Informasi: Jalankan Streamlit dengan Ngrok Tunneling di lingkungan Cloud jika dibutuhkan.")
# Out:
# Informasi: Jalankan Streamlit dengan Ngrok Tunneling di lingkungan Cloud jika dibutuhkan.

# %% [markdown]
# ## 6. Kesimpulan
# Aplikasi Streamlit CanvasGen terverifikasi berjalan lancar, responsif, dan siap untuk disajikan sebagai portofolio maupun dikumpulkan pada submission Dicoding.
